# %%
import pandas as pd
import statistics

data = pd.read_csv('./data/data.csv')
data.head(5)
# Out:
#                   Time  var_a  var_b  var_c  temperture  wind_speed  \
# 0  2022-11-12 23:02:03     24    -65   2424          99           7
# 1  2022-11-12 23:02:03     70     63   2586          99           2
# 2  2022-11-12 23:02:08     36    -89   2794          98           1
# 3  2022-11-12 23:02:13     34      4   2683          97           3
# 4  2022-11-12 23:02:18     23    -77   2961          96           6
#
#    wind_direction  pressure  humidity  rain  snow  cloud  visibility  class
# 0              74      1028        82     4    34     68          23      0
# 1             344      1024        32    66     0     14         100      0
# 2             280      1044        94    75    99     50           9      1
# 3             249      1003        36    85    24     49          52      1
# 4             290      1039        53    52    55     17          85      0

# %%
from datetime import datetime
import os
import random
import mysql.connector
import pandas as pd
from mysql.connector import errorcode
import mysql.connector
import sqlalchemy
from mysql.connector import Error

DB_name = 'weather_data'
Tables = {}

def connectionDB():
    global connection
    try:
        connection = mysql.connector.connect(user='root',
                                            password='Laudarisd1989@@', 
                                            host='localhost', 
                                            database='weather_data', # database should be created before
                                            auth_plugin='mysql_native_password')
        if connection.is_connected():
            db_Info = connection.get_server_info()
            print("Connected to MySQL Server version ", db_Info)
            cursor = connection.cursor()
            cursor.execute("select database();")
            record = cursor.fetchone()
            print ("Your connected to - ", record)
    except Error as e:
        print ("Error while connecting to MySQL", e)
    

    #create database
    # try:
    #     create_database_query = "CREATE DATABASE IF NOT EXISTS {}".format(DB_name)
    #     cursor.execute(create_database_query)
    #     print("Database {} created successfully.".format(DB_name))
    # except Error as e:
    #     print("Error while creating database: ", e)
    # finally:
    #     if connection.is_connected():
    #         cursor.close()
    #         connection.close()
    #         print("MySQL connection is closed")


    columns=['Time', 'var_a', 'var_b', 'var_c', 'temperture', 
                                            'wind_speed', 'wind_direction', 'pressure', 
                                            'humidity', 'rain', 'snow', 'cloud', 'visibility', 'class']
    current_data_time = datetime.now()
    current_data_time = current_data_time.strftime("%Y-%m-%d %H:%M:%S")
    #only date
    #self.current_data_date = datetime.now().date()
    new_row = pd.DataFrame([[current_data_time, 
                                random.randint(0, 100),
                                random.randint(-100, 100), 
                                random.randint(2000, 3000),
                                random.randint(95, 99),
                                random.randint(0, 10),
                                random.randint(0, 360),
                                random.randint(1000, 1050),
                                random.randint(0, 100),
                                random.randint(0, 100),
                                random.randint(0, 100),
                                random.randint(0, 100),
                                random.randint(0, 100),
                                random.randint(0, 1)]], 
                                columns=columns)
    return new_row

    #creatw engine
    #engine = sqlalchemy.create_engine('mysql+mysqlconnector://root:Laudarisd1989@@@localhost:3306/weather_data', echo=False)

   
    

print(connectionDB())
# Out:
# Connected to MySQL Server version  8.0.30
# Your connected to -  ('weather_data',)
#                   Time  var_a  var_b  var_c  temperture  wind_speed  \
# 0  2022-11-13 21:00:13      6     99   2783          97           0
#
#    wind_direction  pressure  humidity  rain  snow  cloud  visibility  class
# 0               2      1019         2    97     7     81          24      1

# %%
from datetime import datetime
import os
import random
import mysql.connector
import pandas as pd
from mysql.connector import errorcode
import mysql.connector
from mysql.connector import Error


def create_server_connection(hoist_name, user_name, user_password, database_name, auth_plugin):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=hoist_name,
            user=user_name,
            passwd=user_password,
            database=database_name,
            auth_plugin=auth_plugin
            #auth_plugin='mysql_native_password'
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection


connection = create_server_connection('localhost', 'root', 'Laudarisd1989@@', 'weather_data', 'mysql_native_password') #'weather_data', # database should be created before
                                                                                    #'mysql_native_password')
# Out:
# MySQL Database connection successful

# %%
DB_name = "weather_data"

def create_database(connection, querry):
    cursor = connection.cursor()
    try:
        cursor.execute(querry)
        print("Database created successfully")
    except Error as err:
        print(f"Error: '{err}'")

create_database_query = "CREATE DATABASE IF NOT EXISTS {}".format(DB_name)
create_database(connection, create_database_query)
# Out:
# Database created successfully

# %%
create_table = """CREATE TABLE weather_data ( time TIMESTAMP NOT NUll PRIMARY KEY,
                                            var_a INT NOT NULL,
                                            var_b INT NOT NULL,
                                            var_c INT NOT NULL,
                                            temperture INT NOT NULL,
                                            wind_speed INT NOT NULL,
                                            wind_direction INT NOT NULL,
                                            pressure INT NOT NULL,
                                            humidity INT NOT NULL,
                                            rain INT NOT NULL,
                                            snow INT NOT NULL,
                                            cloud INT NOT NULL,
                                            visibility INT NOT NULL,
                                            class INT NOT NULL
                                            )"""

connection = create_server_connection('localhost', 'root', 'Laudarisd1989@@', 'weather_data', 'mysql_native_password')
create_database(connection, create_table)
# Out:
# MySQL Database connection successful
# Error: '1050 (42S01): Table 'weather_data' already exists'

# %%
import sqlalchemy


columns=['Time', 'var_a', 'var_b', 'var_c', 'temperture', 
                                            'wind_speed', 'wind_direction', 'pressure', 
                                            'humidity', 'rain', 'snow', 'cloud', 'visibility', 'class']
current_data_time = datetime.now()
current_data_time = current_data_time.strftime("%Y-%m-%d %H:%M:%S")
#only date
#self.current_data_date = datetime.now().date()
new_row = pd.DataFrame([[current_data_time, 
                            random.randint(0, 100),
                            random.randint(-100, 100), 
                            random.randint(2000, 3000),
                            random.randint(95, 99),
                            random.randint(0, 10),
                            random.randint(0, 360),
                            random.randint(1000, 1050),
                            random.randint(0, 100),
                            random.randint(0, 100),
                            random.randint(0, 100),
                            random.randint(0, 100),
                            random.randint(0, 100),
                            random.randint(0, 1)]], 
                            columns=columns)

engine = sqlalchemy.create_engine('mysql+mysqlconnector://{0}:{1}@{2}/{3}'.format('root', 'Laudaris1989@@', 'localhost', 'weather_data'))
new_row.to_sql('weather_data', con=engine, if_exists='append', index=False)

#new_row.to_sql(con=connection, name='weather_data', if_exists='append', index=False)




# enter_value = """INSERT INTO weather_data 
#                 (time, var_a, var_b, var_c, 
#                 temperture, wind_speed, wind_direction, 
#                 pressure, humidity, rain, snow, 
#                 cloud, visibility, class) 
#                 VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"""

# create_database(connection, enter_value)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/mysql/connector/connection_cext.py:268, in CMySQLConnection._open_connection(self)
#     267 try:
# --> 268     self._cmysql.connect(**cnx_kwargs)
#     269     self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown MySQL server host '@@localhost' (8)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
# ...
